# %%
import pandas as pd


df1 = pd.read_parquet(
    "../data/data_hitech_day/",
    filters=[("partition", ">=", 20260401),
            ("partition", "<=", 20260430)],
    engine="pyarrow"
)
df1.head()
# Out:
#   Cell In[38], line 3
#     data/data_hitech_day/partition=20260401/20260505_111741_20863_xxcuu_bfc59188-3fe1-429a-b20a-43a6902b7b3c
#                                                                  ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd

df1 = pd.read_parquet(
    "../data/data_hitech_day/partition=20260424/20260505_120731_22015_xxcuu_c8d6b86e-3055-4580-aa00-54e3d585e352",
    engine="pyarrow"
)
df1.columns.tolist()
# Out:
# ['cus_id',
#  'ten_phuongxa_hoatdong_chinh',
#  'ten_quanhuyen_hoatdong_chinh',
#  'ma_tinh_hoatdong_chinh',
#  'tongdon_diaban_chinh',
#  'tong_tien',
#  'min_tongtien',
#  'max_tongtien',
#  'tong_don',
#  'avg_tongtien',
#  'trong_luong',
#  'min_trongluong',
#  'max_trongluong',
#  'thu_ho',
#  'don_ptc',
#  'don_hoan',
#  'sanluong_phat_yeucau',
#  'don_fail',
#  'khachhang_nhan',
#  'khachhang_nhieudon',
#  'khachhang_moi_flag_daily',
#  'sanluong_cptn',
#  'sanluong_exp',
#  'sanluong_fwd',
#  'sanluong_kho',
#  'sanluong_vt',
#  'sanluong_khac',
#  'lydo_hoan',
#  'so_donhoan_nhieunhat',
#  'lydo_khieunai',
#  'so_khieunai_nhieunhat',
#  'ngay_hoptac',
#  'ngay_sinh',
#  'ten_dangky',
#  'nganh_hang',
#  'loai_khachhang',
#  'thuho_tongdon',
#  'tongdon_cod',
#  'don_ptc_cod',
#  'tong_cuoc_ptc',
#  'ten_xa_dangky',
#  'ten_huyen_dangky',
#  'ten_tinh_dangky']

# %%
import pandas as pd

df = pd.read_parquet(
    "../data/data_hitech_day/",
    filters=[("partition", "=", 20260424)],
    engine="pyarrow"
)
df
# Out:
#           cus_id ten_phuongxa_hoatdong_chinh ten_quanhuyen_hoatdong_chinh  \
# 0       17674027                   PHƯỜNG 13                       QUẬN 6
# 1       10386538            PHƯỜNG DƯƠNG NỘI                 QUẬN HÀ ĐÔNG
# 2       12943424              PHƯỜNG PHÚC LA                 QUẬN HÀ ĐÔNG
# 3        8656447              PHƯỜNG PHÚC LA                 QUẬN HÀ ĐÔNG
# 4       13006033             PHƯỜNG SUỐI HOA           THÀNH PHỐ BẮC NINH
# ...          ...                         ...                          ...
# 136888  17360627                XÃ HÒA PHONG               HUYỆN HÒA VANG
# 136889  14605897          THỊ TRẤN PHÚ PHONG                HUYÊN TÂY SƠN
# 136890    179954            PHƯỜNG ĐỒNG NHÂN            QUẬN HAI BÀ TRƯNG
# 136891  13465273              PHƯỜNG AN BÌNH           THÀNH PHỐ BIÊN HÒA
# 136892  10398864              PHƯỜNG AN BÌNH           THÀNH PHỐ BIÊN HÒA
#
#        ma_tinh_hoatdong_chinh  tongdon_diaban_chinh  tong_tien  min_tongtien  \
# ...

# %%
import pandas as pd


df1 = pd.read_parquet(
    "../data/data_hitech_day/",
    filters=[("partition", ">=", 20260301),
            ("partition", "<=", 20260330)],
    engine="pyarrow"
)
df1
# Out:
#            cus_id ten_phuongxa_hoatdong_chinh ten_quanhuyen_hoatdong_chinh  \
# 0        12810268            PHƯỜNG QUYẾT TÂM             THÀNH PHỐ SƠN LA
# 1         1563572        PHƯỜNG HOÀNG VĂN THỤ        THÀNH PHỐ THÁI NGUYÊN
# 2        14829075              THỊ XÃ CÁI LẬY                HUYỆN CAI LẬY
# 3        17322358               PHƯỜNG PHÚ MỸ        THÀNH PHỐ THỦ DẦU MỘT
# 4         1479112                  XÃ SỦ NGÒI           THÀNH PHỐ HÒA BÌNH
# ...           ...                         ...                          ...
# 7442313   4432198                 XÃ MINH TÂN              HUYỆN ĐÔNG HƯNG
# 7442314  12947349                 XÃ SEN THỦY                HUYỆN LỆ THỦY
# 7442315  10261836                 XÃ ĐỒNG TÂN                HUYỆN ỨNG HÒA
# 7442316  13131955           PHƯỜNG HIỆP THÀNH        THÀNH PHỐ THỦ DẦU MỘT
# 7442317   8809162             PHƯỜNG HÀM RỒNG          THÀNH PHỐ THANH HÓA
#
# ...

# %%
# Kiểm tra số lượng giá trị thiếu trong mỗi cột
missing_count = df1.isnull().sum()

print(missing_count)
# Out:
# cus_id                                0
# ten_phuongxa_hoatdong_chinh      191385
# ten_quanhuyen_hoatdong_chinh     108791
# ma_tinh_hoatdong_chinh                0
# tongdon_diaban_chinh                  0
# tong_tien                             0
# min_tongtien                          0
# max_tongtien                          0
# tong_don                              0
# avg_tongtien                          0
# trong_luong                          64
# min_trongluong                       64
# max_trongluong                       64
# thu_ho                          3168909
# don_ptc                         3168909
# don_hoan                        3168909
# sanluong_phat_yeucau            3168909
# don_fail                        3168909
# khachhang_nhan                        0
# khachhang_nhieudon                    0
# khachhang_moi_flag_daily              0
# sanluong_cptn                         0
# sanluong_exp                          0
# ...

# %%
# Tính tỷ lệ % giá trị thiếu
missing_percentage = (df.isnull().sum() / len(df)) * 100

print(missing_percentage)
# Out:
# cus_id                           0.000000
# ten_phuongxa_hoatdong_chinh      2.860628
# ten_quanhuyen_hoatdong_chinh     1.761230
# ma_tinh_hoatdong_chinh           0.000000
# tongdon_diaban_chinh             0.000000
# tong_tien                        0.000000
# min_tongtien                     0.000000
# max_tongtien                     0.000000
# tong_don                         0.000000
# avg_tongtien                     0.000000
# trong_luong                      0.000000
# min_trongluong                   0.000000
# max_trongluong                   0.000000
# thu_ho                          40.680678
# don_ptc                         40.680678
# don_hoan                        40.680678
# sanluong_phat_yeucau            40.680678
# don_fail                        40.680678
# khachhang_nhan                   0.000000
# khachhang_nhieudon               0.000000
# khachhang_moi_flag_daily         0.000000
# sanluong_cptn                    0.000000
# ...

# %%
# Lấy Top 10 tỉnh
top_10_provinces = df1['ma_tinh_hoatdong_chinh'].value_counts().nlargest(10)

plt.figure(figsize=(10, 6))
top_10_provinces.plot(kind='barh', color='skyblue') # barh là biểu đồ cột ngang

plt.title('Top 10 Tỉnh có số lượng dữ liệu lớn nhất')
plt.xlabel('Số lượng')
plt.ylabel('Mã tỉnh')
plt.gca().invert_yaxis() # Đảo ngược trục y để tỉnh nhiều nhất nằm trên cùng
plt.show()

# %%
df1['avg_tongtien'].describe()
# Out:
# count    7.442318e+06
# mean     6.765237e+04
# std      2.141391e+06
# min     -2.250100e+04
# 25%      1.875000e+04
# 50%      2.950000e+04
# 75%      4.410100e+04
# max      1.980000e+09
# Name: avg_tongtien, dtype: float64

# %%
df1['khachhang_nhan'].describe()
# Out:
# count    7.442318e+06
# mean     7.674239e+00
# std      2.270894e+02
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      4.000000e+00
# max      1.148570e+05
# Name: khachhang_nhan, dtype: float64
